# %%
# !pip install supabase
# Out:
# Requirement already satisfied: supabase in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (2.15.0)
# Requirement already satisfied: gotrue<3.0.0,>=2.11.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from supabase) (2.12.0)
# Requirement already satisfied: httpx<0.29,>=0.26 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from supabase) (0.28.1)
# Requirement already satisfied: postgrest<1.1,>0.19 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from supabase) (1.0.1)
# Requirement already satisfied: realtime<2.5.0,>=2.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from supabase) (2.4.2)
# Requirement already satisfied: storage3<0.12,>=0.10 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from supabase) (0.11.3)
# Requirement already satisfied: supafunc<0.10,>=0.9 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from supabase) (0.9.4)
# Requirement already satisfied: pydantic<3,>=1.10 in /databricks/python3/lib/python3.11/site-packages (from gotrue<3.0.0,>=2.11.0->supabase) (1.10.6)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from gotrue<3.0.0,>=2.11.0->supabase) (2.10.1)
# Requirement already satisfied: pytest-mock<4.0.0,>=3.14.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from gotrue<3.0.0,>=2.11.0->supabase) (3.14.0)
# Requirement already satisfied: anyio in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from httpx<0.29,>=0.26->supabase) (4.9.0)
# Requirement already satisfied: certifi in /databricks/python3/lib/python3.11/site-packages (from httpx<0.29,>=0.26->supabase) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from httpx<0.29,>=0.26->supabase) (1.0.7)
# Requirement already satisfied: idna in /databricks/python3/lib/python3.11/site-packages (from httpx<0.29,>=0.26->supabase) (3.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from httpcore==1.*->httpx<0.29,>=0.26->supabase) (0.14.0)
# Requirement already satisfied: deprecation<3.0.0,>=2.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from postgrest<1.1,>0.19->supabase) (2.1.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.11.14 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from realtime<2.5.0,>=2.4.0->supabase) (3.11.16)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.1 in /databricks/python3/lib/python3.11/site-packages (from realtime<2.5.0,>=2.4.0->supabase) (2.8.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.12.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from realtime<2.5.0,>=2.4.0->supabase) (4.13.0)
# Requirement already satisfied: websockets<15,>=11 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from realtime<2.5.0,>=2.4.0->supabase) (14.2)
# Requirement already satisfied: strenum<0.5.0,>=0.4.15 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from supafunc<0.10,>=0.9->supabase) (0.4.15)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.11.14->realtime<2.5.0,>=2.4.0->supabase) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.11.14->realtime<2.5.0,>=2.4.0->supabase) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.11.14->realtime<2.5.0,>=2.4.0->supabase) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.11.14->realtime<2.5.0,>=2.4.0->supabase) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.11.14->realtime<2.5.0,>=2.4.0->supabase) (6.3.1)
# Requirement already satisfied: propcache>=0.2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.11.14->realtime<2.5.0,>=2.4.0->supabase) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.11.14->realtime<2.5.0,>=2.4.0->supabase) (1.18.3)
# Requirement already satisfied: packaging in /databricks/python3/lib/python3.11/site-packages (from deprecation<3.0.0,>=2.1.0->postgrest<1.1,>0.19->supabase) (23.2)
# Requirement already satisfied: h2<5,>=3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from httpx[http2]<0.29,>=0.26->gotrue<3.0.0,>=2.11.0->supabase) (4.2.0)
# Requirement already satisfied: pytest>=6.2.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from pytest-mock<4.0.0,>=3.14.0->gotrue<3.0.0,>=2.11.0->supabase) (8.3.5)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil<3.0.0,>=2.8.1->realtime<2.5.0,>=2.4.0->supabase) (1.16.0)
# Requirement already satisfied: sniffio>=1.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from anyio->httpx<0.29,>=0.26->supabase) (1.3.1)
# Requirement already satisfied: hyperframe<7,>=6.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]<0.29,>=0.26->gotrue<3.0.0,>=2.11.0->supabase) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]<0.29,>=0.26->gotrue<3.0.0,>=2.11.0->supabase) (4.1.0)
# Requirement already satisfied: iniconfig in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from pytest>=6.2.5->pytest-mock<4.0.0,>=3.14.0->gotrue<3.0.0,>=2.11.0->supabase) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-92691b8d-5bb2-41e4-866e-6bd3533df666/lib/python3.11/site-packages (from pytest>=6.2.5->pytest-mock<4.0.0,>=3.14.0->gotrue<3.0.0,>=2.11.0->supabase) (1.5.0)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# %restart_python

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from supabase import create_client, Client
from datetime import datetime, timedelta
# Out:
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7f5189d2ac00>
# Traceback (most recent call last):
#   File "/databricks/python/lib/python3.11/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/databricks/python/lib/python3.11/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/databricks/python/lib/python3.11/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#                    ^^^^^^^^^^^^^^^^^^
#   File "/databricks/python/lib/python3.11/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
#              ^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'split'

# %%
# get encoded url and api_key from databricks secrets
supabase_url = dbutils.secrets.get(scope='rippl', key='supabase_url')
supabase_key = dbutils.secrets.get(scope='rippl', key='supabase_api_key')

# establish connection with supabase backend
supabase : Client = create_client(supabase_url, supabase_key)

# %%
# Declaring all functions here
def pull_full_table(table_name):
    # got tired of writing this out multiple times so even though it's more clunkly in jupyter notebooks I made a function for this

    # error handling
    # can I check if table doesn't exist in supabase? 

    # get total count of rows
    response = supabase.table(table_name).select("*", count="exact").execute()
    total_count = response.count

    # calculate num_batches
    num_batches = (total_count // 1000) + 1 # can only pull 1000 per batch 

    # print outputs to validate
    print(f"Total Rows in Table: {total_count}")
    print(f"Num Batches to get Total Rows {num_batches}")

    # actually do the loop

    for batch in range(1, num_batches + 1): # start at 1 (or start variable equation doesn't work)
        
        # get start and end of 'range' of rows to call in table
        start = (batch - 1) * 1000  # eg. first batch, will be 0
        end = (batch * 1000) - 1 # eg. first batch, will be 999 (unless less than 999)
        if  end > total_count:
            end = total_count
        
        # print outputs to validate
        print(f"For batch: {batch}, start: {start}, end: {end}")

        # get rows in range(start, end)
        temp_response = supabase.table(table_name).select("*").range(start, end).execute() 

        # get data
        temp_data = temp_response.data
        
        # convert to pandas dataframe for easy handling
        temp_df = pd.DataFrame(temp_data)

        # concatenate (or if batch one, copy)
        if batch == 1:
            result_df = temp_df.copy()

        else:
            result_df = pd.concat([result_df, temp_df], axis=0)

    # reset index and remove prior index
    result_df.reset_index(drop=True, inplace=True)

    return result_df

def delete_table(table_name):
    # so apparently whenever supabase runs a delete command it needs a 'where' command
    # but the way around this is just to run the neq command -- which I guess is looking for a case where 
    # user_id is the 'dummy_id' to make sure it doesn't delete that one
    # but because the dummy_id is intentionally something that shouldn't be a uuid
    # it ends up deleting the whole table 
    dummy_id = "00000000-0000-0000-0000-000000000000"
    response = supabase.table(table_name).delete().neq("user_id", dummy_id).execute()
    print("Deletion response:", response)



def get_post_recommendations(grouped_df, posts_df):
    post_recommendations = []

    for idx, row in grouped_df.iterrows():
        user_id = row['user_id']
        interests = row['interest_id']

        for idx, post_row in posts_df.iterrows():
            post_interest = post_row['interest_id']
            if post_interest in interests:
                # calculate similarity score here

                # popularity
                
                popularity = 1 # placeholder 

                # age of post 

                time_created = pd.to_datetime(post_row['created_at'])

                # removing because they're not needed right now
                # age = datetime.utcnow() - time_created

                # print(age)

                temp_age = 1 # placeholder
                
                post_recommendations.append({
                    # id property should be autogenerated
                    "similarity_score": int((1 * popularity) / temp_age), #placeholder for now
                    "has_been_recommended": True,
                    "timestamp": datetime.utcnow().isoformat(), # converting to ISO to make serializable
                    "embedding": None, 
                    "user_id": user_id,
                    "recommended_post_id": post_row['id'],
                    # "post_interest_id": post_interest # use this property for testing but comment out when actually pushing
                    })
                
    recommendations_df = pd.DataFrame(post_recommendations)
    return recommendations_df


def validate_post_recommendations(merged_recommendations_df):
    # validating outputs
    recommendations_right = 0
    recommendations_wrong = 0

    for idx, row in merged_recommendations_df.iterrows():
        post_interest_id = row['interest_id_y'].strip()
        user_id = row['user_id_x'].strip()
        user_interests = [interest.strip() for interest in row['interest_id_x']]


        if post_interest_id in user_interests:
            recommendations_right += 1
        else:
            recommendations_wrong += 1


    print(f"recommendations right: {recommendations_right}, recommendations_wrong: {recommendations_wrong}")

def remove_duplicate_post_recommendations(new_df_original, old_df_original):

    #creating copies so I don't accidentally 
    new_df = new_df_original.copy()
    old_df = old_df_original.copy()
    
    if new_df.empty:
        print("new df empty, returning old")
        return old_df
    elif old_df.empty:
        print("old df empty, returning new")
        return new_df
    
    # converts all user_ids and recommended_user_ids to strings and strips trailing and leading whitespaces
    for col in ['user_id', 'recommended_post_id']:
        new_df[col] = new_df[col].astype(str).str.strip()
        old_df[col] = old_df[col].astype(str).str.strip()
    


    old_pairs = set(zip(old_df['user_id'], old_df['recommended_post_id']))

    mask = new_df.apply(lambda row: (row['user_id'], row['recommended_post_id']) not in old_pairs, axis=1)

    if not mask.any():
        print("new df is all duplicates of old df, returning old df")
        return old_df

    # using mask and applying mask to original new_df
    filtered_new_df = new_df_original[mask].reset_index(drop=True)

    return filtered_new_df

def check_oldest_timestamp(old_recs_df, day_threshold=7):
    if old_recs_df.empty:
        print("old_recs is empty, therefore cannot be too old")
        return False

    old_copy = old_recs_df.copy()
    
    old_copy['timestamp'] = pd.to_datetime(old_copy['timestamp'], errors='coerce')

    oldest_ts = old_copy['timestamp'].min()


    day_threshold = datetime.now() - timedelta(days=day_threshold)

    if oldest_ts <= day_threshold:
        print("old_recs_df is older than day threshold set, it should be deleted")
        return True
    else:
        print("old_recs_df is not older than day threshold set, it should be kept")
        return False

def delete_table(table_name):
    # so apparently whenever supabase runs a delete command it needs a 'where' command
    # but the way around this is just to run the neq command -- which I guess is looking for a case where 
    # user_id is the 'dummy_id' to make sure it doesn't delete that one
    # but because the dummy_id is intentionally something that shouldn't be a uuid
    # it ends up deleting the whole table 
    dummy_id = "00000000-0000-0000-0000-000000000000"
    response = supabase.table(table_name).delete().neq("user_id", dummy_id).execute()
    print("Deletion response:", response)

# %%
users_df = pull_full_table("users")
users_df
# Out:
# Total Rows in Table: 20
# Num Batches to get Total Rows 1
# For batch: 1, start: 0, end: 20
#                                       id  ...                  created_at
# 0   897a4d99-a0d4-474a-b34d-78ab1e062a93  ...  2025-04-14T02:17:13.164935
# 1   02c3c862-b8a5-4fde-ac56-e3b5545f18d6  ...  2025-04-11T04:11:37.742094
# 2   a46c20e6-1c11-4a59-a70c-1cc22862885d  ...   2025-04-09T23:31:03.00942
# 3   449bc0ab-6942-426e-b573-9cb690ffd1b9  ...  2025-04-10T03:35:57.447764
# 4   3fb510a5-58a0-4994-81ba-29e69fa79db1  ...  2025-04-10T20:14:04.190027
# 5   c2c9fd5e-2040-4ee7-92ec-4bd65a467a27  ...  2025-04-10T20:38:11.824933
# 6   740f8541-0638-4348-8fd9-72453613be4e  ...  2025-04-13T03:15:09.953282
# 7   7ca36877-fc2f-478e-951d-b4af878f25ef  ...  2025-04-15T17:12:07.099672
# 8   ecb95c11-4923-42d0-9a45-01eb27cb832a  ...  2025-04-10T20:19:26.250657
# 9   3e6acdeb-aa9a-47f1-879d-d7139eb98e2f  ...  2025-04-10T04:13:53.414479
# 10  e13ae6de-0656-493c-9165-80c1b0cd9bf6  ...  2025-04-10T00:08:48.194784
# 11  ec03cce8-e743-45af-97e9-71bc05588376  ...  2025-04-13T19:26:05.557248
# 12  f8f9ec17-fb66-4689-abc2-529d61dfb1f4  ...  2025-04-15T17:58:29.199253
# 13  eb88b8b4-bdea-4aa0-af25-ec728d4083e5  ...  2025-04-09T23:26:23.066411
# 14  0b7249ca-cc82-4ff1-9d50-d8d61280b717  ...  2025-04-10T20:25:00.384565
# 15  436c7907-3ded-4313-832a-831fd3259848  ...  2025-04-10T20:11:14.153015
# 16  76e52c42-0d73-42b7-95c4-20aadcd886ae  ...  2025-04-09T23:28:50.884347
# 17  45365d21-9977-4505-a0f0-7f090bc33747  ...  2025-04-10T00:49:25.380794
# 18  a99e13b8-fc64-48c6-a502-72e91972c107  ...  2025-04-10T20:34:15.017889
# 19  355e5f7c-87fa-45c4-a218-ff904b7a1128  ...  2025-04-10T21:13:08.998904
#
# [20 rows x 6 columns]

# %%
user_interest_df = pull_full_table("user_interests")
user_interest_df
# Out:
# Total Rows in Table: 152
# Num Batches to get Total Rows 1
# For batch: 1, start: 0, end: 152
#                                   user_id                           interest_id
# 0    02c3c862-b8a5-4fde-ac56-e3b5545f18d6  15bb36f9-7466-4e83-a148-5096114cce9e
# 1    02c3c862-b8a5-4fde-ac56-e3b5545f18d6  62b86242-7014-499f-9cb9-42cfca036de9
# 2    02c3c862-b8a5-4fde-ac56-e3b5545f18d6  6663208a-593c-4c58-8df2-1cf2fda3cce6
# 3    02c3c862-b8a5-4fde-ac56-e3b5545f18d6  872755d5-698f-4b66-8e80-098c01ca96eb
# 4    02c3c862-b8a5-4fde-ac56-e3b5545f18d6  96081371-66ce-49ef-adf7-a1f90b47fdb3
# ..                                    ...                                   ...
# 147  f8f9ec17-fb66-4689-abc2-529d61dfb1f4  6117a58e-f12f-4af1-b031-da9fa32d0742
# 148  f8f9ec17-fb66-4689-abc2-529d61dfb1f4  7ee3f21b-2e73-4ddd-b6ab-0ae7d7f60a5c
# 149  f8f9ec17-fb66-4689-abc2-529d61dfb1f4  baa13863-6091-4872-ba3d-b29a09af0d05
# 150  f8f9ec17-fb66-4689-abc2-529d61dfb1f4  cbf7c5eb-44e3-4364-b5cd-a0ecd045ee3d
# 151  f8f9ec17-fb66-4689-abc2-529d61dfb1f4  d6d79c59-6338-47b0-b6b4-88bad3f0027e
#
# [152 rows x 2 columns]

# %%
interests_df = pull_full_table("interests")
interests_df
# Out:
# Total Rows in Table: 47
# Num Batches to get Total Rows 1
# For batch: 1, start: 0, end: 47
#                                       id  ...                           category_id
# 0   03f7dc13-cd91-4eaf-95c2-59dc783c8e03  ...  324b188f-361a-416d-9f58-83b9a2e8606c
# 1   06b52f51-32a3-4921-948c-23cb1f474ca3  ...  53ea2977-9a06-4445-bc95-b6d8acf72010
# 2   0f790fe0-7859-4408-9b98-c8cee119d659  ...  53ea2977-9a06-4445-bc95-b6d8acf72010
# 3   15bb36f9-7466-4e83-a148-5096114cce9e  ...  3e50575e-4896-4cf1-a98b-35f629474335
# 4   17a74d46-88b0-40a8-afa8-bbca0d79d285  ...  384da8b9-33f2-4f22-83c7-fc05d8bf2298
# 5   1820882b-7561-4f92-9f8d-8c241be21cf6  ...  384da8b9-33f2-4f22-83c7-fc05d8bf2298
# 6   1888b454-b69e-46bf-bc92-24e6a1085518  ...  9d5bd5f2-ec1d-46ca-9c75-0965c676d465
# 7   1f85d55e-0b0c-4dd7-a9b0-82e4cb699145  ...  3e50575e-4896-4cf1-a98b-35f629474335
# 8   31242d1e-66fe-43fb-8d48-06e751c50e32  ...  324b188f-361a-416d-9f58-83b9a2e8606c
# 9   40ddb76d-be61-4b45-9ec1-1d917e3a08c0  ...  53ea2977-9a06-4445-bc95-b6d8acf72010
# 10  43888455-55cf-4c09-ad26-df7d4673e19c  ...  9d5bd5f2-ec1d-46ca-9c75-0965c676d465
# 11  44227a36-49a0-4f30-94dd-3dc1c4e0a951  ...  53ea2977-9a06-4445-bc95-b6d8acf72010
# 12  4b57788f-1d57-4286-b760-14e6fbccf2f6  ...  211ca1f0-0531-421b-8f0d-5f4bbadf155a
# 13  5bf4236f-11ed-4332-8bb5-c0cc009adc99  ...  384da8b9-33f2-4f22-83c7-fc05d8bf2298
# 14  6117a58e-f12f-4af1-b031-da9fa32d0742  ...  384da8b9-33f2-4f22-83c7-fc05d8bf2298
# 15  62b86242-7014-499f-9cb9-42cfca036de9  ...  3e50575e-4896-4cf1-a98b-35f629474335
# 16  6663208a-593c-4c58-8df2-1cf2fda3cce6  ...  9d9196f4-d3e1-436b-91f7-596393dcc94e
# 17  6ad40466-14f4-4bbd-8d9c-a17590ab2f2c  ...  384da8b9-33f2-4f22-83c7-fc05d8bf2298
# 18  6c22dd13-897c-4b98-95d0-32dda931a2d3  ...  aaeefa37-6181-48a1-91d6-f4e21dd07880
# 19  72a885d5-db6e-4148-9d2a-09347d948451  ...  9d9196f4-d3e1-436b-91f7-596393dcc94e
# 20  7e21b3d7-9a17-4e2a-aa69-a4feba8e7c84  ...  53ea2977-9a06-4445-bc95-b6d8acf72010
# 21  7ee3f21b-2e73-4ddd-b6ab-0ae7d7f60a5c  ...  324b188f-361a-416d-9f58-83b9a2e8606c
# 22  86b64472-50ea-4d2e-b062-69024291cad4  ...  384da8b9-33f2-4f22-83c7-fc05d8bf2298
# 23  872755d5-698f-4b66-8e80-098c01ca96eb  ...  aaeefa37-6181-48a1-91d6-f4e21dd07880
# 24  882a94f2-33f1-412a-931f-96e9dc1b948b  ...  53ea2977-9a06-4445-bc95-b6d8acf72010
# 25  88d66a6d-8bdb-413e-8a21-a2012c737f16  ...  aaeefa37-6181-48a1-91d6-f4e21dd07880
# 26  912f8c61-5ab3-4283-b0ad-015b0038ba23  ...  324b188f-361a-416d-9f58-83b9a2e8606c
# 27  93c2f1f1-c92f-4a33-af8e-669b40d1b34e  ...  3e50575e-4896-4cf1-a98b-35f629474335
# 28  96081371-66ce-49ef-adf7-a1f90b47fdb3  ...  aaeefa37-6181-48a1-91d6-f4e21dd07880
# 29  98df11b0-8fe1-481f-b6e3-464a9b8c141a  ...  3e50575e-4896-4cf1-a98b-35f629474335
# 30  9b9d4d70-dec0-46a9-b7ef-47a773735861  ...  9d9196f4-d3e1-436b-91f7-596393dcc94e
# 31  9ef55e93-a2f1-4f69-a817-70d21e82fce4  ...  384da8b9-33f2-4f22-83c7-fc05d8bf2298
# 32  b0d74040-5f4f-4e22-b874-93a61352346f  ...  3e50575e-4896-4cf1-a98b-35f629474335
# 33  b17e02df-e59b-463d-9bb9-17da4029df75  ...  79b858c1-d262-4917-bad6-de4a00f2631f
# 34  ba47674f-e078-4769-85d8-8e46e20d39c8  ...  aaeefa37-6181-48a1-91d6-f4e21dd07880
# 35  ba5bc1b4-501c-4fbd-899c-63375b9b5ca3  ...  324b188f-361a-416d-9f58-83b9a2e8606c
# 36  baa13863-6091-4872-ba3d-b29a09af0d05  ...  211ca1f0-0531-421b-8f0d-5f4bbadf155a
# 37  c563e58a-aae7-4ff2-ba87-2fc1035168e2  ...  324b188f-361a-416d-9f58-83b9a2e8606c
# 38  cbf7c5eb-44e3-4364-b5cd-a0ecd045ee3d  ...  3e50575e-4896-4cf1-a98b-35f629474335
# 39  d6781357-27e8-426c-b0f2-5441b8a51af0  ...  324b188f-361a-416d-9f58-83b9a2e8606c
# 40  d6d79c59-6338-47b0-b6b4-88bad3f0027e  ...  211ca1f0-0531-421b-8f0d-5f4bbadf155a
# 41  e558275e-00d8-4958-a134-2ac23927b2da  ...  79b858c1-d262-4917-bad6-de4a00f2631f
# 42  e725fe78-8e89-45b2-a7a3-e41e7e5f6733  ...  53ea2977-9a06-4445-bc95-b6d8acf72010
# 43  e7a6d63c-b7bf-49ae-8b15-0c9d4eee16f6  ...  9d9196f4-d3e1-436b-91f7-596393dcc94e
# 44  e8f7f688-a517-46a5-b708-3413bc78fb57  ...  9d9196f4-d3e1-436b-91f7-596393dcc94e
# 45  fea6ed7d-9c6b-44ac-9e8e-198ca9a681a2  ...  0e793b54-ca80-4524-906e-235da748f98f
# 46  ff459b3e-f2aa-4057-b7c2-8a8ddf98bd9d  ...  0e793b54-ca80-4524-906e-235da748f98f
#
# [47 rows x 3 columns]

# %%
n_users = users_df.index.max() + 1 # current number of users
print("n_users: ", n_users)
n_interests = interests_df.index.max() # current number of interests
print("n_interests: ", n_interests)
# Out:
# n_users:  20
# n_interests:  46

# %%
# interests_df['name] is columns of user_interest matrix
# users_df['user_id"] is rows of user_interest matrix
# if user_df['user_id'] has an interest in the column (interests_df['name']) then set the value to 1
# interest_id and user_id will have to be remapped

new_interest_id_map = {}
j = 0
for old in interests_df['id']:
  new_interest_id_map[old] = j
  j += 1

new_user_id_map = {}
i = 0
for old in users_df['id']:
    new_user_id_map[old] = i
    i += 1

new_interest_id_map
# Out:
# {'03f7dc13-cd91-4eaf-95c2-59dc783c8e03': 0,
#  '06b52f51-32a3-4921-948c-23cb1f474ca3': 1,
#  '0f790fe0-7859-4408-9b98-c8cee119d659': 2,
#  '15bb36f9-7466-4e83-a148-5096114cce9e': 3,
#  '17a74d46-88b0-40a8-afa8-bbca0d79d285': 4,
#  '1820882b-7561-4f92-9f8d-8c241be21cf6': 5,
#  '1888b454-b69e-46bf-bc92-24e6a1085518': 6,
#  '1f85d55e-0b0c-4dd7-a9b0-82e4cb699145': 7,
#  '31242d1e-66fe-43fb-8d48-06e751c50e32': 8,
#  '40ddb76d-be61-4b45-9ec1-1d917e3a08c0': 9,
#  '43888455-55cf-4c09-ad26-df7d4673e19c': 10,
#  '44227a36-49a0-4f30-94dd-3dc1c4e0a951': 11,
#  '4b57788f-1d57-4286-b760-14e6fbccf2f6': 12,
#  '5bf4236f-11ed-4332-8bb5-c0cc009adc99': 13,
#  '6117a58e-f12f-4af1-b031-da9fa32d0742': 14,
#  '62b86242-7014-499f-9cb9-42cfca036de9': 15,
#  '6663208a-593c-4c58-8df2-1cf2fda3cce6': 16,
#  '6ad40466-14f4-4bbd-8d9c-a17590ab2f2c': 17,
#  '6c22dd13-897c-4b98-95d0-32dda931a2d3': 18,
#  '72a885d5-db6e-4148-9d2a-09347d948451': 19,
#  '7e21b3d7-9a17-4e2a-aa69-a4feba8e7c84': 20,
#  '7ee3f21b-2e73-4ddd-b6ab-0ae7d7f60a5c': 21,
#  '86b64472-50ea-4d2e-b062-69024291cad4': 22,
#  '872755d5-698f-4b66-8e80-098c01ca96eb': 23,
#  '882a94f2-33f1-412a-931f-96e9dc1b948b': 24,
#  '88d66a6d-8bdb-413e-8a21-a2012c737f16': 25,
#  '912f8c61-5ab3-4283-b0ad-015b0038ba23': 26,
#  '93c2f1f1-c92f-4a33-af8e-669b40d1b34e': 27,
#  '96081371-66ce-49ef-adf7-a1f90b47fdb3': 28,
#  '98df11b0-8fe1-481f-b6e3-464a9b8c141a': 29,
#  '9b9d4d70-dec0-46a9-b7ef-47a773735861': 30,
#  '9ef55e93-a2f1-4f69-a817-70d21e82fce4': 31,
#  'b0d74040-5f4f-4e22-b874-93a61352346f': 32,
#  'b17e02df-e59b-463d-9bb9-17da4029df75': 33,
#  'ba47674f-e078-4769-85d8-8e46e20d39c8': 34,
#  'ba5bc1b4-501c-4fbd-899c-63375b9b5ca3': 35,
#  'baa13863-6091-4872-ba3d-b29a09af0d05': 36,
#  'c563e58a-aae7-4ff2-ba87-2fc1035168e2': 37,
#  'cbf7c5eb-44e3-4364-b5cd-a0ecd045ee3d': 38,
#  'd6781357-27e8-426c-b0f2-5441b8a51af0': 39,
#  'd6d79c59-6338-47b0-b6b4-88bad3f0027e': 40,
#  'e558275e-00d8-4958-a134-2ac23927b2da': 41,
#  'e725fe78-8e89-45b2-a7a3-e41e7e5f6733': 42,
#  'e7a6d63c-b7bf-49ae-8b15-0c9d4eee16f6': 43,
#  'e8f7f688-a517-46a5-b708-3413bc78fb57': 44,
#  'fea6ed7d-9c6b-44ac-9e8e-198ca9a681a2': 45,
#  'ff459b3e-f2aa-4057-b7c2-8a8ddf98bd9d': 46}

# %%
new_user_id_map
# Out:
# {'897a4d99-a0d4-474a-b34d-78ab1e062a93': 0,
#  '02c3c862-b8a5-4fde-ac56-e3b5545f18d6': 1,
#  'a46c20e6-1c11-4a59-a70c-1cc22862885d': 2,
#  '449bc0ab-6942-426e-b573-9cb690ffd1b9': 3,
#  '3fb510a5-58a0-4994-81ba-29e69fa79db1': 4,
#  'c2c9fd5e-2040-4ee7-92ec-4bd65a467a27': 5,
#  '740f8541-0638-4348-8fd9-72453613be4e': 6,
#  '7ca36877-fc2f-478e-951d-b4af878f25ef': 7,
#  'ecb95c11-4923-42d0-9a45-01eb27cb832a': 8,
#  '3e6acdeb-aa9a-47f1-879d-d7139eb98e2f': 9,
#  'e13ae6de-0656-493c-9165-80c1b0cd9bf6': 10,
#  'ec03cce8-e743-45af-97e9-71bc05588376': 11,
#  'f8f9ec17-fb66-4689-abc2-529d61dfb1f4': 12,
#  'eb88b8b4-bdea-4aa0-af25-ec728d4083e5': 13,
#  '0b7249ca-cc82-4ff1-9d50-d8d61280b717': 14,
#  '436c7907-3ded-4313-832a-831fd3259848': 15,
#  '76e52c42-0d73-42b7-95c4-20aadcd886ae': 16,
#  '45365d21-9977-4505-a0f0-7f090bc33747': 17,
#  'a99e13b8-fc64-48c6-a502-72e91972c107': 18,
#  '355e5f7c-87fa-45c4-a218-ff904b7a1128': 19}

# %%
user_interest_df['has_interest'] = 1
user_interest_df
# Out:
#                                   user_id  ... has_interest
# 0    02c3c862-b8a5-4fde-ac56-e3b5545f18d6  ...            1
# 1    02c3c862-b8a5-4fde-ac56-e3b5545f18d6  ...            1
# 2    02c3c862-b8a5-4fde-ac56-e3b5545f18d6  ...            1
# 3    02c3c862-b8a5-4fde-ac56-e3b5545f18d6  ...            1
# 4    02c3c862-b8a5-4fde-ac56-e3b5545f18d6  ...            1
# ..                                    ...  ...          ...
# 147  f8f9ec17-fb66-4689-abc2-529d61dfb1f4  ...            1
# 148  f8f9ec17-fb66-4689-abc2-529d61dfb1f4  ...            1
# 149  f8f9ec17-fb66-4689-abc2-529d61dfb1f4  ...            1
# 150  f8f9ec17-fb66-4689-abc2-529d61dfb1f4  ...            1
# 151  f8f9ec17-fb66-4689-abc2-529d61dfb1f4  ...            1
#
# [152 rows x 3 columns]

# %%
user_interest_matrix_unprocessed = user_interest_df.pivot(index='user_id', columns='interest_id', values='has_interest')
user_interest_matrix_unprocessed
# Out:
# interest_id                           03f7dc13-cd91-4eaf-95c2-59dc783c8e03  ...  ff459b3e-f2aa-4057-b7c2-8a8ddf98bd9d
# user_id                                                                     ...
# 02c3c862-b8a5-4fde-ac56-e3b5545f18d6                                   NaN  ...                                   NaN
# 0b7249ca-cc82-4ff1-9d50-d8d61280b717                                   NaN  ...                                   NaN
# 355e5f7c-87fa-45c4-a218-ff904b7a1128                                   NaN  ...                                   NaN
# 3e6acdeb-aa9a-47f1-879d-d7139eb98e2f                                   NaN  ...                                   NaN
# 3fb510a5-58a0-4994-81ba-29e69fa79db1                                   NaN  ...                                   NaN
# 436c7907-3ded-4313-832a-831fd3259848                                   NaN  ...                                   NaN
# 449bc0ab-6942-426e-b573-9cb690ffd1b9                                   NaN  ...                                   NaN
# 45365d21-9977-4505-a0f0-7f090bc33747                                   NaN  ...                                   NaN
# 740f8541-0638-4348-8fd9-72453613be4e                                   NaN  ...                                   NaN
# 76e52c42-0d73-42b7-95c4-20aadcd886ae                                   NaN  ...                                   NaN
# 7ca36877-fc2f-478e-951d-b4af878f25ef                                   NaN  ...                                   1.0
# 897a4d99-a0d4-474a-b34d-78ab1e062a93                                   NaN  ...                                   NaN
# a46c20e6-1c11-4a59-a70c-1cc22862885d                                   NaN  ...                                   NaN
# a99e13b8-fc64-48c6-a502-72e91972c107                                   1.0  ...                                   NaN
# c2c9fd5e-2040-4ee7-92ec-4bd65a467a27                                   NaN  ...                                   1.0
# e13ae6de-0656-493c-9165-80c1b0cd9bf6                                   NaN  ...                                   NaN
# eb88b8b4-bdea-4aa0-af25-ec728d4083e5                                   NaN  ...                                   NaN
# ec03cce8-e743-45af-97e9-71bc05588376                                   NaN  ...                                   NaN
# ecb95c11-4923-42d0-9a45-01eb27cb832a                                   NaN  ...                                   NaN
# f8f9ec17-fb66-4689-abc2-529d61dfb1f4                                   NaN  ...                                   NaN
#
# [20 rows x 43 columns]

# %%
user_interest_matrix = user_interest_matrix_unprocessed.copy()
user_interest_matrix.index = user_interest_matrix.index.map(lambda uid: new_user_id_map[uid])
user_interest_matrix.index.name = None
user_interest_matrix.index.name = "user_id"
user_interest_matrix
# Out:
# interest_id  03f7dc13-cd91-4eaf-95c2-59dc783c8e03  ...  ff459b3e-f2aa-4057-b7c2-8a8ddf98bd9d
# user_id                                            ...
# 1                                             NaN  ...                                   NaN
# 14                                            NaN  ...                                   NaN
# 19                                            NaN  ...                                   NaN
# 9                                             NaN  ...                                   NaN
# 4                                             NaN  ...                                   NaN
# 15                                            NaN  ...                                   NaN
# 3                                             NaN  ...                                   NaN
# 17                                            NaN  ...                                   NaN
# 6                                             NaN  ...                                   NaN
# 16                                            NaN  ...                                   NaN
# 7                                             NaN  ...                                   1.0
# 0                                             NaN  ...                                   NaN
# 2                                             NaN  ...                                   NaN
# 18                                            1.0  ...                                   NaN
# 5                                             NaN  ...                                   1.0
# 10                                            NaN  ...                                   NaN
# 13                                            NaN  ...                                   NaN
# 11                                            NaN  ...                                   NaN
# 8                                             NaN  ...                                   NaN
# 12                                            NaN  ...                                   NaN
#
# [20 rows x 43 columns]

# %%
posts_df = pull_full_table("posts")
posts_df
# Out:
# Total Rows in Table: 29
# Num Batches to get Total Rows 1
# For batch: 1, start: 0, end: 29
#                                       id  ...           event_date
# 0   f177092a-ec2a-4504-a950-7e61442eedc1  ...  2025-05-03T00:45:00
# 1   8d3889f3-099e-4abd-b04e-02d0a65ba519  ...                 None
# 2   610e4a9c-c1ab-43bb-9e33-80ed4c0a8756  ...  2025-04-20T03:19:00
# 3   8ac2c026-f66d-42f8-8566-9b882a366e68  ...                 None
# 4   912663e7-eaed-416c-a6e2-342efcf4cefc  ...                 None
# 5   08a9cb3f-c5c6-4c96-81c5-e723c9a39dd8  ...                 None
# 6   7cbac01e-bb20-4a1d-93ed-bd53e2bf8c7a  ...                 None
# 7   9380aebc-a2d1-4b9a-b4d7-34a7536e663d  ...                 None
# 8   18432e3c-70ed-4a0c-a5fd-625f769fdd36  ...  2025-04-13T17:56:00
# 9   a2f14788-0163-4395-86f1-51df75ea124c  ...  2025-04-24T10:00:00
# 10  233a7a78-0f94-44d1-a4fe-7086ae1bc283  ...  2025-04-24T23:30:00
# 11  c345fb26-1562-40e6-a14e-06020aa065be  ...  2025-05-20T22:00:00
# 12  9a56a1ac-c180-47fe-b578-06fc7e5863bb  ...                 None
# 13  e064269a-bd0f-4ef6-8a47-400cd69d9ce5  ...                 None
# 14  edad2659-5247-4e10-b792-469b4d4d36d1  ...  2025-04-29T16:00:00
# 15  f69cc62f-9aa4-4bef-9d75-a2a2b523cca2  ...                 None
# 16  85f7c1da-5fe3-4b3c-acec-7ff13ab8fe7c  ...                 None
# 17  30aa1b8f-015a-41d2-8e70-1cbd1440ae54  ...                 None
# 18  037ba871-7624-4623-9361-72d452fc1be0  ...                 None
# 19  e129e022-79ef-40fe-a81e-e60d13989763  ...                 None
# 20  8eb72faf-79b6-45e9-9b4e-a50d99472345  ...                 None
# 21  83ed19ae-e29c-4f5c-a480-cdf781ddad3d  ...                 None
# 22  527d246a-f123-4c86-a862-9524072c0131  ...                 None
# 23  8c81b80c-74db-4202-9fc0-fe2cfe0c7d65  ...  2025-04-23T19:00:00
# 24  e0ee1a26-3671-4d25-b638-a192bc8c1d5c  ...  2025-04-25T14:30:00
# 25  cf083aa2-f768-4283-81b1-1d475e85556f  ...                 None
# 26  2432b903-38f1-4716-af73-cbf25e21a095  ...                 None
# 27  b1b674dd-873a-452f-a7fe-63ce591cb0ab  ...                 None
# 28  2d7e6d6c-b299-4ee0-a6b6-801458dfed4b  ...                 None
#
# [29 rows x 10 columns]

# %%
merged_user_interests = pd.merge(users_df, user_interest_df, left_on='id', right_on='user_id')
merged_user_interests = merged_user_interests.drop(['id', "has_interest", "image", "created_at", "email"], axis=1)
merged_user_interests
# Out:
#                 name  ...                           interest_id
# 0    Sierra Trailson  ...  06b52f51-32a3-4921-948c-23cb1f474ca3
# 1    Sierra Trailson  ...  0f790fe0-7859-4408-9b98-c8cee119d659
# 2    Sierra Trailson  ...  1820882b-7561-4f92-9f8d-8c241be21cf6
# 3    Sierra Trailson  ...  1f85d55e-0b0c-4dd7-a9b0-82e4cb699145
# 4    Sierra Trailson  ...  40ddb76d-be61-4b45-9ec1-1d917e3a08c0
# ..               ...  ...                                   ...
# 147  Samantha Waters  ...  6c22dd13-897c-4b98-95d0-32dda931a2d3
# 148  Samantha Waters  ...  93c2f1f1-c92f-4a33-af8e-669b40d1b34e
# 149  Samantha Waters  ...  98df11b0-8fe1-481f-b6e3-464a9b8c141a
# 150  Samantha Waters  ...  baa13863-6091-4872-ba3d-b29a09af0d05
# 151  Samantha Waters  ...  d6d79c59-6338-47b0-b6b4-88bad3f0027e
#
# [152 rows x 4 columns]

# %%
grouped_df = merged_user_interests.groupby("user_id")['interest_id'].apply(list).reset_index()
grouped_df
# Out:
#                                  user_id                                        interest_id
# 0   02c3c862-b8a5-4fde-ac56-e3b5545f18d6  [15bb36f9-7466-4e83-a148-5096114cce9e, 62b8624...
# 1   0b7249ca-cc82-4ff1-9d50-d8d61280b717  [17a74d46-88b0-40a8-afa8-bbca0d79d285, 1888b45...
# 2   355e5f7c-87fa-45c4-a218-ff904b7a1128  [4b57788f-1d57-4286-b760-14e6fbccf2f6, 6c22dd1...
# 3   3e6acdeb-aa9a-47f1-879d-d7139eb98e2f  [06b52f51-32a3-4921-948c-23cb1f474ca3, 15bb36f...
# 4   3fb510a5-58a0-4994-81ba-29e69fa79db1  [6117a58e-f12f-4af1-b031-da9fa32d0742, 6c22dd1...
# 5   436c7907-3ded-4313-832a-831fd3259848  [06b52f51-32a3-4921-948c-23cb1f474ca3, 0f790fe...
# 6   449bc0ab-6942-426e-b573-9cb690ffd1b9  [1820882b-7561-4f92-9f8d-8c241be21cf6, 4388845...
# 7   45365d21-9977-4505-a0f0-7f090bc33747  [1888b454-b69e-46bf-bc92-24e6a1085518, 40ddb76...
# 8   740f8541-0638-4348-8fd9-72453613be4e  [72a885d5-db6e-4148-9d2a-09347d948451, 86b6447...
# 9   76e52c42-0d73-42b7-95c4-20aadcd886ae  [06b52f51-32a3-4921-948c-23cb1f474ca3, 0f790fe...
# 10  7ca36877-fc2f-478e-951d-b4af878f25ef  [872755d5-698f-4b66-8e80-098c01ca96eb, 88d66a6...
# 11  897a4d99-a0d4-474a-b34d-78ab1e062a93  [06b52f51-32a3-4921-948c-23cb1f474ca3, 0f790fe...
# 12  a46c20e6-1c11-4a59-a70c-1cc22862885d  [06b52f51-32a3-4921-948c-23cb1f474ca3, 0f790fe...
# 13  a99e13b8-fc64-48c6-a502-72e91972c107  [03f7dc13-cd91-4eaf-95c2-59dc783c8e03, 17a74d4...
# 14  c2c9fd5e-2040-4ee7-92ec-4bd65a467a27  [06b52f51-32a3-4921-948c-23cb1f474ca3, 1888b45...
# 15  e13ae6de-0656-493c-9165-80c1b0cd9bf6  [17a74d46-88b0-40a8-afa8-bbca0d79d285, 1f85d55...
# 16  eb88b8b4-bdea-4aa0-af25-ec728d4083e5  [06b52f51-32a3-4921-948c-23cb1f474ca3, 0f790fe...
# 17  ec03cce8-e743-45af-97e9-71bc05588376  [17a74d46-88b0-40a8-afa8-bbca0d79d285, 1888b45...
# 18  ecb95c11-4923-42d0-9a45-01eb27cb832a  [6c22dd13-897c-4b98-95d0-32dda931a2d3, 872755d...
# 19  f8f9ec17-fb66-4689-abc2-529d61dfb1f4  [1888b454-b69e-46bf-bc92-24e6a1085518, 1f85d55...

# %%
post_popularity_df = pull_full_table("post_popularity")
post_popularity_df
# Out:
# Total Rows in Table: 29
# Num Batches to get Total Rows 1
# For batch: 1, start: 0, end: 29
#                                  post_id  likes  ...  reposts  total_engagement
# 0   e0ee1a26-3671-4d25-b638-a192bc8c1d5c      0  ...        0                 0
# 1   2432b903-38f1-4716-af73-cbf25e21a095      0  ...        0                 0
# 2   b1b674dd-873a-452f-a7fe-63ce591cb0ab      0  ...        0                 0
# 3   2d7e6d6c-b299-4ee0-a6b6-801458dfed4b      0  ...        0                 0
# 4   f177092a-ec2a-4504-a950-7e61442eedc1      0  ...        0                 0
# 5   8ac2c026-f66d-42f8-8566-9b882a366e68      0  ...        0                 0
# 6   08a9cb3f-c5c6-4c96-81c5-e723c9a39dd8      0  ...        0                 0
# 7   7cbac01e-bb20-4a1d-93ed-bd53e2bf8c7a      0  ...        0                 0
# 8   9380aebc-a2d1-4b9a-b4d7-34a7536e663d      0  ...        0                 0
# 9   cf083aa2-f768-4283-81b1-1d475e85556f      0  ...        0                 0
# 10  8d3889f3-099e-4abd-b04e-02d0a65ba519      0  ...        0                 0
# 11  912663e7-eaed-416c-a6e2-342efcf4cefc      0  ...        0                 0
# 12  610e4a9c-c1ab-43bb-9e33-80ed4c0a8756      0  ...        0                 0
# 13  18432e3c-70ed-4a0c-a5fd-625f769fdd36      0  ...        0                 0
# 14  a2f14788-0163-4395-86f1-51df75ea124c      0  ...        0                 0
# 15  233a7a78-0f94-44d1-a4fe-7086ae1bc283      0  ...        0                 0
# 16  c345fb26-1562-40e6-a14e-06020aa065be      0  ...        0                 0
# 17  9a56a1ac-c180-47fe-b578-06fc7e5863bb      0  ...        0                 0
# 18  e064269a-bd0f-4ef6-8a47-400cd69d9ce5      0  ...        0                 0
# 19  edad2659-5247-4e10-b792-469b4d4d36d1      0  ...        0                 0
# 20  f69cc62f-9aa4-4bef-9d75-a2a2b523cca2      0  ...        0                 0
# 21  85f7c1da-5fe3-4b3c-acec-7ff13ab8fe7c      0  ...        0                 0
# 22  30aa1b8f-015a-41d2-8e70-1cbd1440ae54      0  ...        0                 0
# 23  037ba871-7624-4623-9361-72d452fc1be0      0  ...        0                 0
# 24  e129e022-79ef-40fe-a81e-e60d13989763      0  ...        0                 0
# 25  8eb72faf-79b6-45e9-9b4e-a50d99472345      0  ...        0                 0
# 26  83ed19ae-e29c-4f5c-a480-cdf781ddad3d      0  ...        0                 0
# 27  527d246a-f123-4c86-a862-9524072c0131      0  ...        0                 0
# 28  8c81b80c-74db-4202-9fc0-fe2cfe0c7d65      0  ...        0                 0
#
# [29 rows x 5 columns]

# %%
recommendations_df = get_post_recommendations(grouped_df, posts_df)
recommendations_df
# Out:
#      similarity_score  ...                   recommended_post_id
# 0                   1  ...  610e4a9c-c1ab-43bb-9e33-80ed4c0a8756
# 1                   1  ...  912663e7-eaed-416c-a6e2-342efcf4cefc
# 2                   1  ...  9380aebc-a2d1-4b9a-b4d7-34a7536e663d
# 3                   1  ...  8d3889f3-099e-4abd-b04e-02d0a65ba519
# 4                   1  ...  08a9cb3f-c5c6-4c96-81c5-e723c9a39dd8
# ..                ...  ...                                   ...
# 117                 1  ...  b1b674dd-873a-452f-a7fe-63ce591cb0ab
# 118                 1  ...  2d7e6d6c-b299-4ee0-a6b6-801458dfed4b
# 119                 1  ...  08a9cb3f-c5c6-4c96-81c5-e723c9a39dd8
# 120                 1  ...  edad2659-5247-4e10-b792-469b4d4d36d1
# 121                 1  ...  e0ee1a26-3671-4d25-b638-a192bc8c1d5c
#
# [122 rows x 6 columns]

# %%
old_user_post_recommendations_df = pull_full_table("user_post_recommendations")
old_user_post_recommendations_df
# Out:
# Total Rows in Table: 122
# Num Batches to get Total Rows 1
# For batch: 1, start: 0, end: 122
#                                        id  ...                   recommended_post_id
# 0    14d3ec99-d878-445e-ad43-170c50c520f1  ...  610e4a9c-c1ab-43bb-9e33-80ed4c0a8756
# 1    2a04081a-c0bf-41d1-8d7c-3a5a5daba1a6  ...  912663e7-eaed-416c-a6e2-342efcf4cefc
# 2    556353e7-b45f-40df-b80d-72ab4a7c5bc7  ...  9380aebc-a2d1-4b9a-b4d7-34a7536e663d
# 3    1c22839f-1f42-4897-99ac-ab155363af7a  ...  8d3889f3-099e-4abd-b04e-02d0a65ba519
# 4    35ced054-d1f5-4f54-a647-3a2c438b53a2  ...  08a9cb3f-c5c6-4c96-81c5-e723c9a39dd8
# ..                                    ...  ...                                   ...
# 117  a2ac9e30-eb7f-4227-ac58-2150bf9b8b6a  ...  b1b674dd-873a-452f-a7fe-63ce591cb0ab
# 118  681ac01d-5ffd-40df-8921-a455c44849cf  ...  2d7e6d6c-b299-4ee0-a6b6-801458dfed4b
# 119  3941e954-4fdf-468c-a19e-53c09238b755  ...  08a9cb3f-c5c6-4c96-81c5-e723c9a39dd8
# 120  ed18b65b-e939-4a5c-97a6-eac8c5aee84a  ...  edad2659-5247-4e10-b792-469b4d4d36d1
# 121  6e2d7d9c-66b1-4e1d-839a-135dcf4245be  ...  e0ee1a26-3671-4d25-b638-a192bc8c1d5c
#
# [122 rows x 7 columns]

# %%
# unrealistic threshold to prevent accidental deletion
day_threshold = 100

# if oldest date found in old_user_user_recommendations has a 7 day difference between it and utcnow()
if check_oldest_timestamp(old_user_post_recommendations_df, day_threshold=day_threshold):
    # uncomment when live
    delete_table("user_post_recommendations")
else:
    print("removing duplicates from new batch of recommendations_df")
    recommendations_df = remove_duplicate_post_recommendations(recommendations_df, old_user_post_recommendations_df)
    recommendations_df
# Out:
# old_recs is empty, therefore cannot be too old
# removing duplicates from new batch of recommendations_df
# old df empty, returning new

# %%
recommendations_df
# Out:
#      similarity_score  ...                   recommended_post_id
# 0                   1  ...  610e4a9c-c1ab-43bb-9e33-80ed4c0a8756
# 1                   1  ...  912663e7-eaed-416c-a6e2-342efcf4cefc
# 2                   1  ...  9380aebc-a2d1-4b9a-b4d7-34a7536e663d
# 3                   1  ...  8d3889f3-099e-4abd-b04e-02d0a65ba519
# 4                   1  ...  08a9cb3f-c5c6-4c96-81c5-e723c9a39dd8
# ..                ...  ...                                   ...
# 117                 1  ...  b1b674dd-873a-452f-a7fe-63ce591cb0ab
# 118                 1  ...  2d7e6d6c-b299-4ee0-a6b6-801458dfed4b
# 119                 1  ...  08a9cb3f-c5c6-4c96-81c5-e723c9a39dd8
# 120                 1  ...  edad2659-5247-4e10-b792-469b4d4d36d1
# 121                 1  ...  e0ee1a26-3671-4d25-b638-a192bc8c1d5c
#
# [122 rows x 6 columns]

# %%
merged_recommendations_df = pd.merge(recommendations_df, grouped_df, on='user_id')
merged_recommendations_df = pd.merge(merged_recommendations_df, posts_df, left_on='recommended_post_id', right_on='id')
merged_recommendations_df
# Out:
#      similarity_score  ...           event_date
# 0                   1  ...  2025-04-20T03:19:00
# 1                   1  ...  2025-04-20T03:19:00
# 2                   1  ...  2025-04-20T03:19:00
# 3                   1  ...                 None
# 4                   1  ...                 None
# ..                ...  ...                  ...
# 117                 1  ...                 None
# 118                 1  ...                 None
# 119                 1  ...                 None
# 120                 1  ...                 None
# 121                 1  ...                 None
#
# [122 rows x 17 columns]

# %%
validate_post_recommendations(merged_recommendations_df)
# Out:
# recommendations right: 122, recommendations_wrong: 0

# %%
# here we filter by various attributes (age, location ?)

# %%
# convert to dictionary, this is the format that the supabase client expects
records = recommendations_df.to_dict(orient="records") 
records
# Out:
# [{'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.499380',
#   'embedding': None,
#   'user_id': '02c3c862-b8a5-4fde-ac56-e3b5545f18d6',
#   'recommended_post_id': '610e4a9c-c1ab-43bb-9e33-80ed4c0a8756'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.499652',
#   'embedding': None,
#   'user_id': '02c3c862-b8a5-4fde-ac56-e3b5545f18d6',
#   'recommended_post_id': '912663e7-eaed-416c-a6e2-342efcf4cefc'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.499931',
#   'embedding': None,
#   'user_id': '02c3c862-b8a5-4fde-ac56-e3b5545f18d6',
#   'recommended_post_id': '9380aebc-a2d1-4b9a-b4d7-34a7536e663d'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.501307',
#   'embedding': None,
#   'user_id': '0b7249ca-cc82-4ff1-9d50-d8d61280b717',
#   'recommended_post_id': '8d3889f3-099e-4abd-b04e-02d0a65ba519'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.501576',
#   'embedding': None,
#   'user_id': '0b7249ca-cc82-4ff1-9d50-d8d61280b717',
#   'recommended_post_id': '08a9cb3f-c5c6-4c96-81c5-e723c9a39dd8'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.501797',
#   'embedding': None,
#   'user_id': '0b7249ca-cc82-4ff1-9d50-d8d61280b717',
#   'recommended_post_id': '18432e3c-70ed-4a0c-a5fd-625f769fdd36'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.501924',
#   'embedding': None,
#   'user_id': '0b7249ca-cc82-4ff1-9d50-d8d61280b717',
#   'recommended_post_id': 'a2f14788-0163-4395-86f1-51df75ea124c'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.502461',
#   'embedding': None,
#   'user_id': '0b7249ca-cc82-4ff1-9d50-d8d61280b717',
#   'recommended_post_id': '30aa1b8f-015a-41d2-8e70-1cbd1440ae54'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.502722',
#   'embedding': None,
#   'user_id': '0b7249ca-cc82-4ff1-9d50-d8d61280b717',
#   'recommended_post_id': '83ed19ae-e29c-4f5c-a480-cdf781ddad3d'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.502846',
#   'embedding': None,
#   'user_id': '0b7249ca-cc82-4ff1-9d50-d8d61280b717',
#   'recommended_post_id': '527d246a-f123-4c86-a862-9524072c0131'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.504033',
#   'embedding': None,
#   'user_id': '355e5f7c-87fa-45c4-a218-ff904b7a1128',
#   'recommended_post_id': 'edad2659-5247-4e10-b792-469b4d4d36d1'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.504477',
#   'embedding': None,
#   'user_id': '355e5f7c-87fa-45c4-a218-ff904b7a1128',
#   'recommended_post_id': 'e129e022-79ef-40fe-a81e-e60d13989763'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.504856',
#   'embedding': None,
#   'user_id': '355e5f7c-87fa-45c4-a218-ff904b7a1128',
#   'recommended_post_id': 'e0ee1a26-3671-4d25-b638-a192bc8c1d5c'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.504994',
#   'embedding': None,
#   'user_id': '355e5f7c-87fa-45c4-a218-ff904b7a1128',
#   'recommended_post_id': 'cf083aa2-f768-4283-81b1-1d475e85556f'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.505842',
#   'embedding': None,
#   'user_id': '3e6acdeb-aa9a-47f1-879d-d7139eb98e2f',
#   'recommended_post_id': '7cbac01e-bb20-4a1d-93ed-bd53e2bf8c7a'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.506676',
#   'embedding': None,
#   'user_id': '3e6acdeb-aa9a-47f1-879d-d7139eb98e2f',
#   'recommended_post_id': '8c81b80c-74db-4202-9fc0-fe2cfe0c7d65'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.506845',
#   'embedding': None,
#   'user_id': '3e6acdeb-aa9a-47f1-879d-d7139eb98e2f',
#   'recommended_post_id': 'cf083aa2-f768-4283-81b1-1d475e85556f'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.507168',
#   'embedding': None,
#   'user_id': '3fb510a5-58a0-4994-81ba-29e69fa79db1',
#   'recommended_post_id': 'f177092a-ec2a-4504-a950-7e61442eedc1'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.507334',
#   'embedding': None,
#   'user_id': '3fb510a5-58a0-4994-81ba-29e69fa79db1',
#   'recommended_post_id': '610e4a9c-c1ab-43bb-9e33-80ed4c0a8756'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.507587',
#   'embedding': None,
#   'user_id': '3fb510a5-58a0-4994-81ba-29e69fa79db1',
#   'recommended_post_id': '912663e7-eaed-416c-a6e2-342efcf4cefc'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.508153',
#   'embedding': None,
#   'user_id': '3fb510a5-58a0-4994-81ba-29e69fa79db1',
#   'recommended_post_id': 'edad2659-5247-4e10-b792-469b4d4d36d1'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.508710',
#   'embedding': None,
#   'user_id': '3fb510a5-58a0-4994-81ba-29e69fa79db1',
#   'recommended_post_id': 'e0ee1a26-3671-4d25-b638-a192bc8c1d5c'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.508842',
#   'embedding': None,
#   'user_id': '3fb510a5-58a0-4994-81ba-29e69fa79db1',
#   'recommended_post_id': 'cf083aa2-f768-4283-81b1-1d475e85556f'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.509478',
#   'embedding': None,
#   'user_id': '436c7907-3ded-4313-832a-831fd3259848',
#   'recommended_post_id': '7cbac01e-bb20-4a1d-93ed-bd53e2bf8c7a'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.509744',
#   'embedding': None,
#   'user_id': '436c7907-3ded-4313-832a-831fd3259848',
#   'recommended_post_id': '18432e3c-70ed-4a0c-a5fd-625f769fdd36'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.509898',
#   'embedding': None,
#   'user_id': '436c7907-3ded-4313-832a-831fd3259848',
#   'recommended_post_id': 'a2f14788-0163-4395-86f1-51df75ea124c'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.510080',
#   'embedding': None,
#   'user_id': '436c7907-3ded-4313-832a-831fd3259848',
#   'recommended_post_id': 'c345fb26-1562-40e6-a14e-06020aa065be'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.510210',
#   'embedding': None,
#   'user_id': '436c7907-3ded-4313-832a-831fd3259848',
#   'recommended_post_id': '9a56a1ac-c180-47fe-b578-06fc7e5863bb'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.510603',
#   'embedding': None,
#   'user_id': '436c7907-3ded-4313-832a-831fd3259848',
#   'recommended_post_id': '8eb72faf-79b6-45e9-9b4e-a50d99472345'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.510780',
#   'embedding': None,
#   'user_id': '436c7907-3ded-4313-832a-831fd3259848',
#   'recommended_post_id': '83ed19ae-e29c-4f5c-a480-cdf781ddad3d'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.510919',
#   'embedding': None,
#   'user_id': '436c7907-3ded-4313-832a-831fd3259848',
#   'recommended_post_id': '527d246a-f123-4c86-a862-9524072c0131'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.511053',
#   'embedding': None,
#   'user_id': '436c7907-3ded-4313-832a-831fd3259848',
#   'recommended_post_id': '8c81b80c-74db-4202-9fc0-fe2cfe0c7d65'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.512478',
#   'embedding': None,
#   'user_id': '449bc0ab-6942-426e-b573-9cb690ffd1b9',
#   'recommended_post_id': '527d246a-f123-4c86-a862-9524072c0131'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.512705',
#   'embedding': None,
#   'user_id': '449bc0ab-6942-426e-b573-9cb690ffd1b9',
#   'recommended_post_id': 'cf083aa2-f768-4283-81b1-1d475e85556f'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.513199',
#   'embedding': None,
#   'user_id': '45365d21-9977-4505-a0f0-7f090bc33747',
#   'recommended_post_id': '8ac2c026-f66d-42f8-8566-9b882a366e68'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.513369',
#   'embedding': None,
#   'user_id': '45365d21-9977-4505-a0f0-7f090bc33747',
#   'recommended_post_id': '08a9cb3f-c5c6-4c96-81c5-e723c9a39dd8'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.513775',
#   'embedding': None,
#   'user_id': '45365d21-9977-4505-a0f0-7f090bc33747',
#   'recommended_post_id': 'e064269a-bd0f-4ef6-8a47-400cd69d9ce5'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.513984',
#   'embedding': None,
#   'user_id': '45365d21-9977-4505-a0f0-7f090bc33747',
#   'recommended_post_id': 'edad2659-5247-4e10-b792-469b4d4d36d1'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.514481',
#   'embedding': None,
#   'user_id': '45365d21-9977-4505-a0f0-7f090bc33747',
#   'recommended_post_id': '527d246a-f123-4c86-a862-9524072c0131'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.514653',
#   'embedding': None,
#   'user_id': '45365d21-9977-4505-a0f0-7f090bc33747',
#   'recommended_post_id': 'e0ee1a26-3671-4d25-b638-a192bc8c1d5c'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.515231',
#   'embedding': None,
#   'user_id': '740f8541-0638-4348-8fd9-72453613be4e',
#   'recommended_post_id': '8ac2c026-f66d-42f8-8566-9b882a366e68'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.515757',
#   'embedding': None,
#   'user_id': '740f8541-0638-4348-8fd9-72453613be4e',
#   'recommended_post_id': 'e064269a-bd0f-4ef6-8a47-400cd69d9ce5'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.515905',
#   'embedding': None,
#   'user_id': '740f8541-0638-4348-8fd9-72453613be4e',
#   'recommended_post_id': 'edad2659-5247-4e10-b792-469b4d4d36d1'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.516109',
#   'embedding': None,
#   'user_id': '740f8541-0638-4348-8fd9-72453613be4e',
#   'recommended_post_id': 'f69cc62f-9aa4-4bef-9d75-a2a2b523cca2'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.516246',
#   'embedding': None,
#   'user_id': '740f8541-0638-4348-8fd9-72453613be4e',
#   'recommended_post_id': '85f7c1da-5fe3-4b3c-acec-7ff13ab8fe7c'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.516680',
#   'embedding': None,
#   'user_id': '740f8541-0638-4348-8fd9-72453613be4e',
#   'recommended_post_id': 'e0ee1a26-3671-4d25-b638-a192bc8c1d5c'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.516801',
#   'embedding': None,
#   'user_id': '740f8541-0638-4348-8fd9-72453613be4e',
#   'recommended_post_id': 'cf083aa2-f768-4283-81b1-1d475e85556f'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.516963',
#   'embedding': None,
#   'user_id': '740f8541-0638-4348-8fd9-72453613be4e',
#   'recommended_post_id': 'b1b674dd-873a-452f-a7fe-63ce591cb0ab'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.517515',
#   'embedding': None,
#   'user_id': '76e52c42-0d73-42b7-95c4-20aadcd886ae',
#   'recommended_post_id': '7cbac01e-bb20-4a1d-93ed-bd53e2bf8c7a'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.517795',
#   'embedding': None,
#   'user_id': '76e52c42-0d73-42b7-95c4-20aadcd886ae',
#   'recommended_post_id': 'c345fb26-1562-40e6-a14e-06020aa065be'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.517923',
#   'embedding': None,
#   'user_id': '76e52c42-0d73-42b7-95c4-20aadcd886ae',
#   'recommended_post_id': '9a56a1ac-c180-47fe-b578-06fc7e5863bb'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.518177',
#   'embedding': None,
#   'user_id': '76e52c42-0d73-42b7-95c4-20aadcd886ae',
#   'recommended_post_id': 'edad2659-5247-4e10-b792-469b4d4d36d1'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.518528',
#   'embedding': None,
#   'user_id': '76e52c42-0d73-42b7-95c4-20aadcd886ae',
#   'recommended_post_id': '8eb72faf-79b6-45e9-9b4e-a50d99472345'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.518731',
#   'embedding': None,
#   'user_id': '76e52c42-0d73-42b7-95c4-20aadcd886ae',
#   'recommended_post_id': '8c81b80c-74db-4202-9fc0-fe2cfe0c7d65'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.518849',
#   'embedding': None,
#   'user_id': '76e52c42-0d73-42b7-95c4-20aadcd886ae',
#   'recommended_post_id': 'e0ee1a26-3671-4d25-b638-a192bc8c1d5c'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.519277',
#   'embedding': None,
#   'user_id': '7ca36877-fc2f-478e-951d-b4af878f25ef',
#   'recommended_post_id': 'f177092a-ec2a-4504-a950-7e61442eedc1'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.519419',
#   'embedding': None,
#   'user_id': '7ca36877-fc2f-478e-951d-b4af878f25ef',
#   'recommended_post_id': '8d3889f3-099e-4abd-b04e-02d0a65ba519'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.519622',
#   'embedding': None,
#   'user_id': '7ca36877-fc2f-478e-951d-b4af878f25ef',
#   'recommended_post_id': '912663e7-eaed-416c-a6e2-342efcf4cefc'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.519934',
#   'embedding': None,
#   'user_id': '7ca36877-fc2f-478e-951d-b4af878f25ef',
#   'recommended_post_id': '233a7a78-0f94-44d1-a4fe-7086ae1bc283'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.520405',
#   'embedding': None,
#   'user_id': '7ca36877-fc2f-478e-951d-b4af878f25ef',
#   'recommended_post_id': '30aa1b8f-015a-41d2-8e70-1cbd1440ae54'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.520919',
#   'embedding': None,
#   'user_id': '7ca36877-fc2f-478e-951d-b4af878f25ef',
#   'recommended_post_id': '2432b903-38f1-4716-af73-cbf25e21a095'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.521093',
#   'embedding': None,
#   'user_id': '7ca36877-fc2f-478e-951d-b4af878f25ef',
#   'recommended_post_id': '2d7e6d6c-b299-4ee0-a6b6-801458dfed4b'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.521623',
#   'embedding': None,
#   'user_id': '897a4d99-a0d4-474a-b34d-78ab1e062a93',
#   'recommended_post_id': '7cbac01e-bb20-4a1d-93ed-bd53e2bf8c7a'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.521946',
#   'embedding': None,
#   'user_id': '897a4d99-a0d4-474a-b34d-78ab1e062a93',
#   'recommended_post_id': '9a56a1ac-c180-47fe-b578-06fc7e5863bb'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.522107',
#   'embedding': None,
#   'user_id': '897a4d99-a0d4-474a-b34d-78ab1e062a93',
#   'recommended_post_id': 'edad2659-5247-4e10-b792-469b4d4d36d1'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.522497',
#   'embedding': None,
#   'user_id': '897a4d99-a0d4-474a-b34d-78ab1e062a93',
#   'recommended_post_id': '8eb72faf-79b6-45e9-9b4e-a50d99472345'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.522779',
#   'embedding': None,
#   'user_id': '897a4d99-a0d4-474a-b34d-78ab1e062a93',
#   'recommended_post_id': '8c81b80c-74db-4202-9fc0-fe2cfe0c7d65'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.522995',
#   'embedding': None,
#   'user_id': '897a4d99-a0d4-474a-b34d-78ab1e062a93',
#   'recommended_post_id': 'e0ee1a26-3671-4d25-b638-a192bc8c1d5c'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.523687',
#   'embedding': None,
#   'user_id': 'a46c20e6-1c11-4a59-a70c-1cc22862885d',
#   'recommended_post_id': '912663e7-eaed-416c-a6e2-342efcf4cefc'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.523882',
#   'embedding': None,
#   'user_id': 'a46c20e6-1c11-4a59-a70c-1cc22862885d',
#   'recommended_post_id': '7cbac01e-bb20-4a1d-93ed-bd53e2bf8c7a'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.524058',
#   'embedding': None,
#   'user_id': 'a46c20e6-1c11-4a59-a70c-1cc22862885d',
#   'recommended_post_id': '18432e3c-70ed-4a0c-a5fd-625f769fdd36'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.524184',
#   'embedding': None,
#   'user_id': 'a46c20e6-1c11-4a59-a70c-1cc22862885d',
#   'recommended_post_id': 'a2f14788-0163-4395-86f1-51df75ea124c'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.524445',
#   'embedding': None,
#   'user_id': 'a46c20e6-1c11-4a59-a70c-1cc22862885d',
#   'recommended_post_id': '9a56a1ac-c180-47fe-b578-06fc7e5863bb'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.525043',
#   'embedding': None,
#   'user_id': 'a46c20e6-1c11-4a59-a70c-1cc22862885d',
#   'recommended_post_id': '8eb72faf-79b6-45e9-9b4e-a50d99472345'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.525195',
#   'embedding': None,
#   'user_id': 'a46c20e6-1c11-4a59-a70c-1cc22862885d',
#   'recommended_post_id': '83ed19ae-e29c-4f5c-a480-cdf781ddad3d'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.525378',
#   'embedding': None,
#   'user_id': 'a46c20e6-1c11-4a59-a70c-1cc22862885d',
#   'recommended_post_id': '8c81b80c-74db-4202-9fc0-fe2cfe0c7d65'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.525974',
#   'embedding': None,
#   'user_id': 'a99e13b8-fc64-48c6-a502-72e91972c107',
#   'recommended_post_id': '8d3889f3-099e-4abd-b04e-02d0a65ba519'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.526404',
#   'embedding': None,
#   'user_id': 'a99e13b8-fc64-48c6-a502-72e91972c107',
#   'recommended_post_id': '9380aebc-a2d1-4b9a-b4d7-34a7536e663d'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.527024',
#   'embedding': None,
#   'user_id': 'a99e13b8-fc64-48c6-a502-72e91972c107',
#   'recommended_post_id': '30aa1b8f-015a-41d2-8e70-1cbd1440ae54'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.527187',
#   'embedding': None,
#   'user_id': 'a99e13b8-fc64-48c6-a502-72e91972c107',
#   'recommended_post_id': '037ba871-7624-4623-9361-72d452fc1be0'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.528107',
#   'embedding': None,
#   'user_id': 'c2c9fd5e-2040-4ee7-92ec-4bd65a467a27',
#   'recommended_post_id': '8d3889f3-099e-4abd-b04e-02d0a65ba519'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.528547',
#   'embedding': None,
#   'user_id': 'c2c9fd5e-2040-4ee7-92ec-4bd65a467a27',
#   'recommended_post_id': '08a9cb3f-c5c6-4c96-81c5-e723c9a39dd8'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.528968',
#   'embedding': None,
#   'user_id': 'c2c9fd5e-2040-4ee7-92ec-4bd65a467a27',
#   'recommended_post_id': '7cbac01e-bb20-4a1d-93ed-bd53e2bf8c7a'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.529687',
#   'embedding': None,
#   'user_id': 'c2c9fd5e-2040-4ee7-92ec-4bd65a467a27',
#   'recommended_post_id': '18432e3c-70ed-4a0c-a5fd-625f769fdd36'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.530129',
#   'embedding': None,
#   'user_id': 'c2c9fd5e-2040-4ee7-92ec-4bd65a467a27',
#   'recommended_post_id': 'a2f14788-0163-4395-86f1-51df75ea124c'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.530493',
#   'embedding': None,
#   'user_id': 'c2c9fd5e-2040-4ee7-92ec-4bd65a467a27',
#   'recommended_post_id': '233a7a78-0f94-44d1-a4fe-7086ae1bc283'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.531129',
#   'embedding': None,
#   'user_id': 'c2c9fd5e-2040-4ee7-92ec-4bd65a467a27',
#   'recommended_post_id': 'edad2659-5247-4e10-b792-469b4d4d36d1'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.531524',
#   'embedding': None,
#   'user_id': 'c2c9fd5e-2040-4ee7-92ec-4bd65a467a27',
#   'recommended_post_id': '85f7c1da-5fe3-4b3c-acec-7ff13ab8fe7c'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.531788',
#   'embedding': None,
#   'user_id': 'c2c9fd5e-2040-4ee7-92ec-4bd65a467a27',
#   'recommended_post_id': '30aa1b8f-015a-41d2-8e70-1cbd1440ae54'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.532398',
#   'embedding': None,
#   'user_id': 'c2c9fd5e-2040-4ee7-92ec-4bd65a467a27',
#   'recommended_post_id': '83ed19ae-e29c-4f5c-a480-cdf781ddad3d'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.532744',
#   'embedding': None,
#   'user_id': 'c2c9fd5e-2040-4ee7-92ec-4bd65a467a27',
#   'recommended_post_id': '8c81b80c-74db-4202-9fc0-fe2cfe0c7d65'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.532925',
#   'embedding': None,
#   'user_id': 'c2c9fd5e-2040-4ee7-92ec-4bd65a467a27',
#   'recommended_post_id': 'e0ee1a26-3671-4d25-b638-a192bc8c1d5c'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.533217',
#   'embedding': None,
#   'user_id': 'c2c9fd5e-2040-4ee7-92ec-4bd65a467a27',
#   'recommended_post_id': '2432b903-38f1-4716-af73-cbf25e21a095'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.533827',
#   'embedding': None,
#   'user_id': 'e13ae6de-0656-493c-9165-80c1b0cd9bf6',
#   'recommended_post_id': '9380aebc-a2d1-4b9a-b4d7-34a7536e663d'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.534439',
#   'embedding': None,
#   'user_id': 'e13ae6de-0656-493c-9165-80c1b0cd9bf6',
#   'recommended_post_id': 'edad2659-5247-4e10-b792-469b4d4d36d1'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.535005',
#   'embedding': None,
#   'user_id': 'e13ae6de-0656-493c-9165-80c1b0cd9bf6',
#   'recommended_post_id': 'e0ee1a26-3671-4d25-b638-a192bc8c1d5c'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.535686',
#   'embedding': None,
#   'user_id': 'eb88b8b4-bdea-4aa0-af25-ec728d4083e5',
#   'recommended_post_id': '8ac2c026-f66d-42f8-8566-9b882a366e68'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.535928',
#   'embedding': None,
#   'user_id': 'eb88b8b4-bdea-4aa0-af25-ec728d4083e5',
#   'recommended_post_id': '7cbac01e-bb20-4a1d-93ed-bd53e2bf8c7a'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.536123',
#   'embedding': None,
#   'user_id': 'eb88b8b4-bdea-4aa0-af25-ec728d4083e5',
#   'recommended_post_id': '18432e3c-70ed-4a0c-a5fd-625f769fdd36'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.536359',
#   'embedding': None,
#   'user_id': 'eb88b8b4-bdea-4aa0-af25-ec728d4083e5',
#   'recommended_post_id': 'a2f14788-0163-4395-86f1-51df75ea124c'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.536645',
#   'embedding': None,
#   'user_id': 'eb88b8b4-bdea-4aa0-af25-ec728d4083e5',
#   'recommended_post_id': '9a56a1ac-c180-47fe-b578-06fc7e5863bb'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.536782',
#   'embedding': None,
#   'user_id': 'eb88b8b4-bdea-4aa0-af25-ec728d4083e5',
#   'recommended_post_id': 'e064269a-bd0f-4ef6-8a47-400cd69d9ce5'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.536925',
#   'embedding': None,
#   'user_id': 'eb88b8b4-bdea-4aa0-af25-ec728d4083e5',
#   'recommended_post_id': 'edad2659-5247-4e10-b792-469b4d4d36d1'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.537380',
#   'embedding': None,
#   'user_id': 'eb88b8b4-bdea-4aa0-af25-ec728d4083e5',
#   'recommended_post_id': '8eb72faf-79b6-45e9-9b4e-a50d99472345'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.537540',
#   'embedding': None,
#   'user_id': 'eb88b8b4-bdea-4aa0-af25-ec728d4083e5',
#   'recommended_post_id': '83ed19ae-e29c-4f5c-a480-cdf781ddad3d'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.537717',
#   'embedding': None,
#   'user_id': 'eb88b8b4-bdea-4aa0-af25-ec728d4083e5',
#   'recommended_post_id': '8c81b80c-74db-4202-9fc0-fe2cfe0c7d65'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.537844',
#   'embedding': None,
#   'user_id': 'eb88b8b4-bdea-4aa0-af25-ec728d4083e5',
#   'recommended_post_id': 'e0ee1a26-3671-4d25-b638-a192bc8c1d5c'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.538487',
#   'embedding': None,
#   'user_id': 'ec03cce8-e743-45af-97e9-71bc05588376',
#   'recommended_post_id': '08a9cb3f-c5c6-4c96-81c5-e723c9a39dd8'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.538968',
#   'embedding': None,
#   'user_id': 'ec03cce8-e743-45af-97e9-71bc05588376',
#   'recommended_post_id': 'edad2659-5247-4e10-b792-469b4d4d36d1'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.539213',
#   'embedding': None,
#   'user_id': 'ec03cce8-e743-45af-97e9-71bc05588376',
#   'recommended_post_id': '85f7c1da-5fe3-4b3c-acec-7ff13ab8fe7c'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.539700',
#   'embedding': None,
#   'user_id': 'ec03cce8-e743-45af-97e9-71bc05588376',
#   'recommended_post_id': '527d246a-f123-4c86-a862-9524072c0131'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.539880',
#   'embedding': None,
#   'user_id': 'ec03cce8-e743-45af-97e9-71bc05588376',
#   'recommended_post_id': 'e0ee1a26-3671-4d25-b638-a192bc8c1d5c'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.540346',
#   'embedding': None,
#   'user_id': 'ecb95c11-4923-42d0-9a45-01eb27cb832a',
#   'recommended_post_id': '610e4a9c-c1ab-43bb-9e33-80ed4c0a8756'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.540646',
#   'embedding': None,
#   'user_id': 'ecb95c11-4923-42d0-9a45-01eb27cb832a',
#   'recommended_post_id': '912663e7-eaed-416c-a6e2-342efcf4cefc'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.541192',
#   'embedding': None,
#   'user_id': 'ecb95c11-4923-42d0-9a45-01eb27cb832a',
#   'recommended_post_id': 'edad2659-5247-4e10-b792-469b4d4d36d1'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.541353',
#   'embedding': None,
#   'user_id': 'ecb95c11-4923-42d0-9a45-01eb27cb832a',
#   'recommended_post_id': 'f69cc62f-9aa4-4bef-9d75-a2a2b523cca2'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.542042',
#   'embedding': None,
#   'user_id': 'ecb95c11-4923-42d0-9a45-01eb27cb832a',
#   'recommended_post_id': 'e0ee1a26-3671-4d25-b638-a192bc8c1d5c'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.542280',
#   'embedding': None,
#   'user_id': 'ecb95c11-4923-42d0-9a45-01eb27cb832a',
#   'recommended_post_id': 'b1b674dd-873a-452f-a7fe-63ce591cb0ab'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.542437',
#   'embedding': None,
#   'user_id': 'ecb95c11-4923-42d0-9a45-01eb27cb832a',
#   'recommended_post_id': '2d7e6d6c-b299-4ee0-a6b6-801458dfed4b'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.542980',
#   'embedding': None,
#   'user_id': 'f8f9ec17-fb66-4689-abc2-529d61dfb1f4',
#   'recommended_post_id': '08a9cb3f-c5c6-4c96-81c5-e723c9a39dd8'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.543474',
#   'embedding': None,
#   'user_id': 'f8f9ec17-fb66-4689-abc2-529d61dfb1f4',
#   'recommended_post_id': 'edad2659-5247-4e10-b792-469b4d4d36d1'},
#  {'similarity_score': 1,
#   'has_been_recommended': True,
#   'timestamp': '2025-04-16T21:13:10.544125',
#   'embedding': None,
#   'user_id': 'f8f9ec17-fb66-4689-abc2-529d61dfb1f4',
#   'recommended_post_id': 'e0ee1a26-3671-4d25-b638-a192bc8c1d5c'}]

# %%
# don't uncomment out the push table line until ready

response = supabase.table("user_post_recommendations").insert(records).execute()

# %%
# things still to do for this specific script

#2. TODO Add the popularity/age element to the similarity score
#3. TODO Figure out how to do the filtering part 
#4. TODO validate that the script runs when and how I want to when I'm not there
#6. TODO remove unnecessary elements from the script
#7. TODO Optimize time complexity and computational complexity of the script
